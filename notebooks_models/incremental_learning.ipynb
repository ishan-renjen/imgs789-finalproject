# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix

import numpy as np
import pandas as pd

# %%
#load embedding matrices
t1_euclidean_embeddings  = np.load('exps/eval_t1_hierarchical_split/euclidean/hyp_embeddings.npy', allow_pickle=True)
t1_euclidean_labels      = np.load('exps/eval_t1_hierarchical_split/euclidean/hyp_labels.npy', allow_pickle=True)
t1_euclidean_match_flags = np.load('exps/eval_t1_hierarchical_split/euclidean/hyp_match_flags.npy', allow_pickle=True)

t2_euclidean_embeddings  = np.load('exps/eval_t2_ft_hierarchical_split/euclidean/hyp_embeddings.npy', allow_pickle=True)
t2_euclidean_labels      = np.load('exps/eval_t2_ft_hierarchical_split/euclidean/hyp_labels.npy', allow_pickle=True)
t2_euclidean_match_flags = np.load('exps/eval_t2_ft_hierarchical_split/euclidean/hyp_match_flags.npy', allow_pickle=True)

t3_euclidean_embeddings  = np.load('exps/eval_t3_ft_hierarchical_split/euclidean/hyp_embeddings.npy', allow_pickle=True)
t3_euclidean_labels      = np.load('exps/eval_t3_ft_hierarchical_split/euclidean/hyp_labels.npy', allow_pickle=True)
t3_euclidean_match_flags = np.load('exps/eval_t3_ft_hierarchical_split/euclidean/hyp_match_flags.npy', allow_pickle=True)

t4_euclidean_embeddings  = np.load('exps/eval_t4_ft_hierarchical_split/euclidean/hyp_embeddings.npy', allow_pickle=True)
t4_euclidean_labels      = np.load('exps/eval_t4_ft_hierarchical_split/euclidean/hyp_labels.npy', allow_pickle=True)
t4_euclidean_match_flags = np.load('exps/eval_t4_ft_hierarchical_split/euclidean/hyp_match_flags.npy', allow_pickle=True)

superclass_map = {0:'vehicle', 1:'vehicle', 2:'outdoor', 3:'outdoor', 4:'animal', 5:'animal', 6:'animal', 7:'accessory', 8:'sports', 9:'sports', 10:'kitchen', 
                  11:'kitchen',12:'food', 13:'food', 14:'furniture', 15:'furniture', 16:'electronic', 17:'appliance',  18:'appliance', 19:'indoor', #end task 1 

                  20:'person', 21:'vehicle', 22:'vehicle', 23:'outdoor', 24:'animal', 25:'animal', 26:'accessory', 27:'sports', 28:'sports', 29:'kitchen',
                  30:'food',  31:'food', 32:'food',  33:'furniture', 34:'furniture', 35:'electronic', 36:'electronic', 37:'appliance',  38:'indoor', 39:'indoor', #end task 2

                  40: 'vehicle', 41: 'vehicle', 42: 'outdoor', 43: 'animal', 44: 'animal', 45: 'animal', 46: 'accessory', 47: 'sports', 48: 'sports', 49: 'sports', 50: 'kitchen',
                  51: 'kitchen', 52: 'food', 53: 'food', 54: 'kitchen', 55: 'electronic', 56: 'electronic', 57: 'appliance', 58: 'indoor', 59: 'indoor',#end task 3

                  60: 'vehicle', 61: 'vehicle', 62: 'outdoor', 63: 'animal', 64: 'animal', 65: 'accessory', 66: 'accessory', 67: 'sports', 68: 'sports', 69: 'sports', 
                  70: 'kitchen', 71: 'kitchen', 72: 'food', 73: 'food', 74: 'food', 75: 'kitchen', 76: 'electronic', 77: 'appliance', 78: 'indoor', 79: 'indoor' #end task 4
                  }

#*****************************T1********************************************
t1_emb_euclidean         = t1_euclidean_embeddings.reshape(-1, 256)
t1_labels_euclidean      = t1_euclidean_labels.reshape(-1)
t1_match_flags_euclidean = t1_euclidean_match_flags.reshape(-1)

t1_euclidean_embeddings_matched = t1_emb_euclidean[t1_match_flags_euclidean]
t1_euclidean_labels_matched = t1_labels_euclidean[t1_match_flags_euclidean]

t1_euclidean_emb_mask = t1_euclidean_labels_matched != 80 
t1_euclidean_labels_known = t1_euclidean_labels_matched[t1_euclidean_emb_mask]
t1_euclidean_embeddings_known = t1_euclidean_embeddings_matched[t1_euclidean_emb_mask]
#*****************************T2********************************************
t2_emb_euclidean         = t2_euclidean_embeddings.reshape(-1, 256)
t2_labels_euclidean      = t2_euclidean_labels.reshape(-1)
t2_match_flags_euclidean = t2_euclidean_match_flags.reshape(-1)

t2_euclidean_embeddings_matched = t2_emb_euclidean[t2_match_flags_euclidean]
t2_euclidean_labels_matched = t2_labels_euclidean[t2_match_flags_euclidean]

t2_euclidean_emb_mask = t2_euclidean_labels_matched != 80 
t2_euclidean_labels_known = t2_euclidean_labels_matched[t2_euclidean_emb_mask]
t2_euclidean_embeddings_known = t2_euclidean_embeddings_matched[t2_euclidean_emb_mask]
#***********************************T3**************************************
t3_emb_euclidean                 = t3_euclidean_embeddings.reshape(-1, 256)
t3_labels_euclidean              = t3_euclidean_labels.reshape(-1)
t3_match_flags_euclidean         = t3_euclidean_match_flags.reshape(-1)

t3_euclidean_embeddings_matched  = t3_emb_euclidean[t3_match_flags_euclidean]
t3_euclidean_labels_matched      = t3_labels_euclidean[t3_match_flags_euclidean]

t3_euclidean_emb_mask            = t3_euclidean_labels_matched != 80 
t3_euclidean_labels_known        = t3_euclidean_labels_matched[t3_euclidean_emb_mask]
t3_euclidean_embeddings_known    = t3_euclidean_embeddings_matched[t3_euclidean_emb_mask]
#***********************************T4**************************************
t4_emb_euclidean                 = t4_euclidean_embeddings.reshape(-1, 256)
t4_labels_euclidean              = t4_euclidean_labels.reshape(-1)
t4_match_flags_euclidean         = t4_euclidean_match_flags.reshape(-1)

t4_euclidean_embeddings_matched  = t4_emb_euclidean[t4_match_flags_euclidean]
t4_euclidean_labels_matched      = t4_labels_euclidean[t4_match_flags_euclidean]

t4_euclidean_emb_mask            = t4_euclidean_labels_matched != 80 
t4_euclidean_labels_known        = t4_euclidean_labels_matched[t4_euclidean_emb_mask]
t4_euclidean_embeddings_known    = t4_euclidean_embeddings_matched[t4_euclidean_emb_mask]

# %%
prototype_bank = dict()
replay_buffer = dict()

#set limits for replay buffer
num_samples = 20
rep_frac = 0.7
hard_frac = 1 - rep_frac

#rng
seed=42

#samples
rep_samples  = int(rep_frac * num_samples)
hard_samples = int(hard_frac * num_samples)

def l2_normalize(x):
    pca = PCA(n_components=24, random_state=42)
    class_embeddings_reduced = pca.fit_transform(x)
    return x / (np.linalg.norm(class_embeddings_reduced, axis=1, keepdims=True))

def cosine_loss(a, b, axis=-1):
    a = np.asarray(a, dtype=np.float64)
    b = np.asarray(b, dtype=np.float64)

    dot = np.sum(a * b, axis=axis)
    norm_a = np.linalg.norm(a, axis=axis)
    norm_b = np.linalg.norm(b, axis=axis)

    cos_sim = dot / (norm_a * norm_b)
    return 1.0 - cos_sim

# %%
def nearest_real_points_to_centers(X, centers):
    chosen = []
    used = set()

    for center in centers:
        dists = np.linalg.norm(X-center, axis=1)
        order = np.argsort(dists)
        for idx in order:
            if idx not in used:
                used.add(idx)
                chosen.append(idx)
                break
    return np.array(chosen, dtype=int)

def select_representative_examples(class_emb):
    if len(class_emb) <= rep_samples:
        return class_emb.copy()

    k_eff = min(rep_samples, len(class_emb))
    km = KMeans(n_clusters=k_eff, random_state=seed, n_init=10)
    km.fit(class_emb)

    rep_idx = nearest_real_points_to_centers(class_emb, km.cluster_centers_)
    return class_emb[rep_idx]

def compute_margin_scores(class_emb, class_num, prototypes):
    true_protos = prototypes[class_num]
    d_true = np.min(cosine_loss(class_emb[:, None, :], true_protos[None, :, :], axis=2),axis=1)

    d_wrong = np.full(len(class_emb), np.inf)

    for other_cls, other_protos in prototypes.items():
        if other_cls == class_num:
            continue
        d_cls = np.min(cosine_loss(class_emb[:, None, :],other_protos[None, :, :], axis=2),axis=1)
        d_wrong = np.minimum(d_wrong, d_cls)

    margins = d_wrong - d_true
    return margins

def select_hard_examples(class_emb, class_num, prototypes, num_hard):
    if len(class_emb) <= num_hard:
        return class_emb.copy()

    margins = compute_margin_scores(class_emb, class_num, prototypes)
    hard_idx = np.argsort(margins)[:num_hard]
    return class_emb[hard_idx]

def update_replay_buffer(support_emb, support_labels, prototype_bank, replay_buffer, class_list):
    new_buffer = dict(replay_buffer)

    for class_idx in class_list:
        class_emb = support_emb[support_labels == class_idx]
        if len(class_emb) == 0:
            continue

        rep = select_representative_examples(class_emb)

        if len(prototype_bank) > 1 and hard_samples > 0:
            hard = select_hard_examples(class_emb, class_idx, prototype_bank, hard_samples)
            combined = np.vstack([rep, hard]) if len(hard) > 0 else rep
        else:
            combined = rep

        combined = np.unique(combined, axis=0)

        if len(combined) > num_samples:
            combined = combined[:num_samples]

        new_buffer[class_idx] = combined

    return new_buffer

# %%
def split_data(emb, labels, shot_size):
    rng = np.random.default_rng(seed)

    support_x, support_y = [], []
    query_x, query_y = [], []

    for cls in np.unique(labels):
        idx = np.where(labels == cls)[0]
        rng.shuffle(idx)

        # keep at least 1 query example when possible
        n_support = min(shot_size, max(1, len(idx) - 1))
        support_idx = idx[:n_support]
        query_idx = idx[n_support:]

        support_x.append(emb[support_idx])
        support_y.append(labels[support_idx])

        if len(query_idx) > 0:
            query_x.append(emb[query_idx])
            query_y.append(labels[query_idx])

    support_x = np.concatenate(support_x, axis=0)
    support_y = np.concatenate(support_y, axis=0)
    query_x = np.concatenate(query_x, axis=0) 
    query_y = np.concatenate(query_y, axis=0)

    return support_x, support_y, query_x, query_y

def create_class_prototypes(support_emb, support_labels, replay_buffer, class_list, k):
    prototype_bank = {}

    for class_idx in class_list:
        current_mem = []

        if class_idx in replay_buffer and len(replay_buffer[class_idx]) > 0:
            current_mem.append(replay_buffer[class_idx])

        current_support_items = support_emb[support_labels == class_idx]
        if len(current_support_items) > 0:
            current_mem.append(current_support_items)

        if len(current_mem) == 0:
            continue

        support_2d = np.vstack(current_mem)

        k_eff = min(k, len(support_2d))
        if k_eff == 1:
            prototype_bank[class_idx] = support_2d.mean(axis=0, keepdims=True)
        else:
            k_means = KMeans(n_clusters=k_eff, random_state=seed, n_init=10)
            k_means.fit(support_2d)
            prototype_bank[class_idx] = k_means.cluster_centers_

    return prototype_bank

def predict_with_prototypes(query, prototype_bank):
    pred = None
    min_dist = float("inf")

    for class_idx, prototype_list in prototype_bank.items():
        dist = [cosine_loss(query, proto) for proto in prototype_list]
        min_class_dist = np.min(dist)

        if min_class_dist < min_dist:
            min_dist = min_class_dist
            pred = class_idx

    return pred, min_dist

def batch_predict(query_emb, prototype_bank):
    preds, dists = [], []
    for q in query_emb:
        p, d = predict_with_prototypes(q, prototype_bank)
        preds.append(p)
        dists.append(d)
    return np.array(preds), np.array(dists)

# %%
def class_accuracy_table(y_true, y_pred):
    rows = []
    for cls in np.unique(y_true):
        mask = (y_true == cls)
        rows.append({"class_id": int(cls), "n_query": int(mask.sum()), "accuracy": float((y_pred[mask] == y_true[mask]).mean())})
    return pd.DataFrame(rows).sort_values(["accuracy", "n_query"], ascending=[True, False]).reset_index(drop=True)

def class_accuracy_table_with_superclass(y_true, y_pred, superclass_map):
    rows = []
    for cls in np.unique(y_true):
        mask = (y_true == cls)
        rows.append({
            "class_id": int(cls),
            "superclass": superclass_map[int(cls)],
            "n_query": int(mask.sum()),
            "accuracy": float((y_pred[mask] == y_true[mask]).mean())
        })
    return pd.DataFrame(rows)

def superclass_internal_variation_table(y_true, y_pred, superclass_map):
    class_df = class_accuracy_table_with_superclass(y_true, y_pred, superclass_map)
    out = (class_df.groupby("superclass", as_index=False).agg(num_classes=("class_id", "count"),
                                                           mean_class_acc=("accuracy", "mean"), 
                                                           std_class_acc=("accuracy", "std"), min_class_acc=("accuracy", "min"), 
                                                           max_class_acc=("accuracy", "max")).sort_values("std_class_acc", ascending=False).reset_index(drop=True))

    return out

def superclass_accuracy_table(y_true, y_pred, superclass_map):
    true_sc = np.array([superclass_map[int(x)] for x in y_true], dtype=object)
    pred_sc = np.array([superclass_map[int(x)] for x in y_pred], dtype=object)

    rows = []
    for sc in sorted(np.unique(true_sc)):
        mask = (true_sc == sc)
        rows.append({ "superclass": sc, "n_query": int(mask.sum()), "accuracy": float((pred_sc[mask] == true_sc[mask]).mean())})

    return pd.DataFrame(rows).sort_values(["accuracy", "n_query"], ascending=[True, False]).reset_index(drop=True)

# %%
def run_incremental_fewshot(tasks, shot_size=5, k=3):
    replay_buffer = {}
    seen_classes = []
    results = []
    per_task_details = []

    for task_id, (emb, labels) in enumerate(tasks, start=1):
        support_emb, support_labels, query_emb, query_labels = split_data(emb, labels, shot_size=shot_size)

        task_classes = sorted(np.unique(labels).tolist())
        seen_classes = sorted(set(seen_classes).union(task_classes))

        prototype_bank = create_class_prototypes(support_emb, support_labels, replay_buffer, seen_classes, k=k)

        preds, dists = batch_predict(query_emb, prototype_bank)
        acc = np.mean(preds == query_labels) if len(query_labels) > 0 else np.nan

        class_table = class_accuracy_table(query_labels, preds)
        superclass_table = superclass_accuracy_table(query_labels, preds, superclass_map)
        superclass_variation_table = superclass_internal_variation_table(query_labels, preds, superclass_map)

        results.append({
            "task": task_id, "accuracy": acc, "num_seen_classes": len(seen_classes),
            "macro_class_acc": class_table["accuracy"].mean(), "class_acc_std": class_table["accuracy"].std(ddof=0),
            "macro_superclass_acc": superclass_table["accuracy"].mean(), "superclass_acc_std": superclass_table["accuracy"].std(ddof=0)})

        per_task_details.append({
            "task": task_id, "y_true": query_labels.copy(), "y_pred": preds.copy(), "dists": dists.copy(),
            "class_table": class_table, "superclass_table": superclass_table, "superclass_variation_table": superclass_variation_table})

        replay_buffer = update_replay_buffer(support_emb=support_emb, support_labels=support_labels, prototype_bank=prototype_bank, replay_buffer=replay_buffer, class_list=task_classes)

    return results, replay_buffer, per_task_details

# %%
def superclass_labels(y, superclass_map):
    return np.array([superclass_map[int(x)] for x in y], dtype=object)

def normalized_confusion(y_true, y_pred, labels):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm = cm.astype(float)
    row_sums = cm.sum(axis=1, keepdims=True)
    cm_norm = np.divide(cm, row_sums, out=np.zeros_like(cm), where=row_sums != 0)
    return pd.DataFrame(cm_norm, index=labels, columns=labels)

def superclass_confusion_table(y_true, y_pred, superclass_map):
    true_sc = superclass_labels(y_true, superclass_map)
    pred_sc = superclass_labels(y_pred, superclass_map)
    labels = sorted(np.unique(true_sc))
    return normalized_confusion(true_sc, pred_sc, labels)

def superclass_failure_breakdown(y_true, y_pred, superclass_map):
    true_sc = superclass_labels(y_true, superclass_map)
    pred_sc = superclass_labels(y_pred, superclass_map)

    rows = []
    for sc in sorted(np.unique(true_sc)):
        mask = (true_sc == sc)
        yt = y_true[mask]
        yp = y_pred[mask]
        psc = pred_sc[mask]

        total = len(yt)
        correct = (yp == yt)
        same_sc_wrong = (~correct) & (psc == sc)
        cross_sc_wrong = (psc != sc)

        wrong_dest = pd.Series(psc[cross_sc_wrong]).value_counts()
        top_wrong_sc = wrong_dest.index[0] if len(wrong_dest) > 0 else None
        top_wrong_sc_frac = float(wrong_dest.iloc[0] / total) if len(wrong_dest) > 0 else 0.0

        rows.append({
            "superclass": sc, "n_query": total, "acc": float(correct.mean()), "same_superclass_error_rate": float(same_sc_wrong.mean()),
            "cross_superclass_error_rate": float(cross_sc_wrong.mean()), "top_wrong_superclass": top_wrong_sc, "top_wrong_superclass_frac": top_wrong_sc_frac})

    return pd.DataFrame(rows).sort_values("acc").reset_index(drop=True)

def within_superclass_confusion(y_true, y_pred, superclass_map, target_superclass):
    class_ids = sorted([
        cls for cls, sc in superclass_map.items()
        if sc == target_superclass
    ])

    mask = np.array([superclass_map[int(y)] == target_superclass for y in y_true])
    yt = y_true[mask]
    yp = y_pred[mask]

    # keep only predictions that also land inside this superclass
    keep_cols = class_ids
    cm = confusion_matrix(yt, yp, labels=keep_cols).astype(float)

    row_sums = cm.sum(axis=1, keepdims=True)
    cm_norm = np.divide(cm, row_sums, out=np.zeros_like(cm), where=row_sums != 0)

    return pd.DataFrame(cm_norm, index=class_ids, columns=class_ids)

def top_confusion_pairs_within_superclass(y_true, y_pred, superclass_map, target_superclass, top_k=10):
    mask = np.array([superclass_map[int(y)] == target_superclass for y in y_true])
    yt = y_true[mask]
    yp = y_pred[mask]

    rows = []
    for t, p in zip(yt, yp):
        if t != p and superclass_map[int(t)] == target_superclass and superclass_map.get(int(p), None) == target_superclass:
            rows.append((int(t), int(p)))

    if len(rows) == 0:
        return pd.DataFrame(columns=["true_class", "pred_class", "count"])

    df = pd.DataFrame(rows, columns=["true_class", "pred_class"])
    return (
        df.value_counts()
        .reset_index(name="count")
        .sort_values("count", ascending=False)
        .head(top_k)
        .reset_index(drop=True)
    )

# %%
tasks = [(t1_euclidean_embeddings_known, t1_euclidean_labels_known),
         (t2_euclidean_embeddings_known, t2_euclidean_labels_known),
         (t3_euclidean_embeddings_known, t3_euclidean_labels_known),
         (t4_euclidean_embeddings_known, t4_euclidean_labels_known)]

results, replay_buffer, per_task_details = run_incremental_fewshot(tasks, shot_size=20, k=3)

print(pd.DataFrame(results))

y_true3 = per_task_details[3]["y_true"]
y_pred3 = per_task_details[3]["y_pred"]

y_true2 = per_task_details[2]["y_true"]
y_pred2 = per_task_details[2]["y_pred"]

y_true1 = per_task_details[1]["y_true"]
y_pred1 = per_task_details[1]["y_pred"]

y_true0 = per_task_details[0]["y_true"]
y_pred0 = per_task_details[0]["y_pred"]

print("******************************TASK 1******************************")
print(per_task_details[0]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true0, y_pred0, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true0, y_pred0, superclass_map)
print(task4_failure)
print("******************************TASK 2******************************")
print(per_task_details[1]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true1, y_pred1, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true1, y_pred1, superclass_map)
print(task4_failure)
print("******************************TASK 3******************************")
print(per_task_details[2]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true2, y_pred2, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true2, y_pred2, superclass_map)
print(task4_failure)
print("******************************TASK 4******************************")
print(per_task_details[3]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true3, y_pred3, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true3, y_pred3, superclass_map)
print(task4_failure)
# Out:
#    task  accuracy  num_seen_classes  macro_class_acc  class_acc_std  \
# 0     1  0.882633                20         0.868732       0.078920
# 1     2  0.793079                40         0.723878       0.166961
# 2     3  0.723700                60         0.677462       0.141158
# 3     4  0.700054                80         0.658050       0.156416
#
#    macro_superclass_acc  superclass_acc_std
# 0              0.909009            0.046251
# 1              0.834027            0.071025
# 2              0.817141            0.059336
# 3              0.803993            0.070983
# ******************************TASK 1******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0         food            2        0.750270       0.124691       0.662100
# 1    appliance            2        0.749593       0.071286       0.699187
# 2    furniture            2        0.858451       0.059345       0.816488
# 3       sports            2        0.946583       0.043548       0.915789
# 4       animal            3        0.902165       0.034122       0.863636
# 5      vehicle            2        0.929266       0.019411       0.915541
# 6      outdoor            2        0.934290       0.005631       0.930308
# 7      kitchen            2        0.886561       0.002806       0.884577
# 8    accessory            1        0.849003            NaN       0.849003
# 9   electronic            1        0.798507            NaN       0.798507
# 10      indoor            1        0.910605            NaN       0.910605
#
#     max_class_acc
# 0        0.838440
# 1        0.800000
# 2        0.900415
# 3        0.977376
# 4        0.928571
# 5        0.942992
# 6        0.938272
# 7        0.888545
# 8        0.849003
# 9        0.798507
# 10       0.910605
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.849003  0.017094   0.002849    0.000000  0.000000   0.034188
# animal       0.002500  0.926250   0.013750    0.001250  0.002500   0.028750
# appliance    0.018987  0.000000   0.898734    0.006329  0.000000   0.025316
# electronic   0.022388  0.000000   0.067164    0.798507  0.000000   0.041045
# food         0.013841  0.006920   0.005190    0.000000  0.897924   0.036332
# furniture    0.018887  0.002485   0.008946    0.000497  0.000994   0.914016
# indoor       0.003506  0.000876   0.013146    0.002629  0.002629   0.024540
# kitchen      0.009036  0.001506   0.003765    0.000000  0.013554   0.012048
# outdoor      0.000000  0.004298   0.001433    0.001433  0.001433   0.005731
# sports       0.015823  0.000000   0.003165    0.000000  0.003165   0.006329
# vehicle      0.002717  0.000453   0.006341    0.000000  0.001359   0.006793
#
#               indoor   kitchen   outdoor    sports   vehicle
# accessory   0.000000  0.022792  0.017094  0.019943  0.037037
# animal      0.000000  0.001250  0.006250  0.002500  0.015000
# appliance   0.006329  0.031646  0.000000  0.000000  0.012658
# electronic  0.022388  0.022388  0.014925  0.000000  0.011194
# food        0.000000  0.024221  0.000000  0.001730  0.013841
# furniture   0.010437  0.033300  0.000497  0.000000  0.009940
# indoor      0.910605  0.034181  0.001753  0.000000  0.006135
# kitchen     0.003012  0.951054  0.003012  0.000753  0.002259
# outdoor     0.000000  0.002865  0.949857  0.000000  0.032951
# sports      0.000000  0.000000  0.000000  0.958861  0.012658
# vehicle     0.000453  0.001812  0.034873  0.000906  0.944293
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    appliance      158  0.721519                    0.177215
# 1         food      578  0.771626                    0.126298
# 2   electronic      268  0.798507                    0.000000
# 3    furniture     2012  0.826541                    0.087475
# 4    accessory      351  0.849003                    0.000000
# 5      kitchen     1328  0.885542                    0.065512
# 6       animal      800  0.905000                    0.021250
# 7       indoor     1141  0.910605                    0.000000
# 8      outdoor      698  0.931232                    0.018625
# 9      vehicle     2208  0.939312                    0.004982
# 10      sports      316  0.958861                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.101266              kitchen
# 1                      0.102076            furniture
# 2                      0.201493            appliance
# 3                      0.085984              kitchen
# 4                      0.150997              vehicle
# 5                      0.048946                 food
# 6                      0.073750            furniture
# 7                      0.089395              kitchen
# 8                      0.050143              vehicle
# 9                      0.055707              outdoor
# 10                     0.041139            accessory
#
#     top_wrong_superclass_frac
# 0                    0.031646
# 1                    0.036332
# 2                    0.067164
# 3                    0.033300
# 4                    0.037037
# 5                    0.013554
# 6                    0.028750
# 7                    0.034181
# 8                    0.032951
# 9                    0.034873
# 10                   0.015823
# ******************************TASK 2******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    appliance            3        0.484785       0.422162       0.000000
# 1    accessory            2        0.616472       0.247313       0.441595
# 2         food            5        0.737316       0.148927       0.570776
# 3      vehicle            4        0.832305       0.147340       0.635135
# 4       sports            4        0.657185       0.139285       0.448980
# 5    furniture            4        0.696110       0.113597       0.576763
# 6      outdoor            3        0.818692       0.094039       0.763371
# 7       animal            5        0.826070       0.076103       0.730952
# 8   electronic            3        0.740400       0.073027       0.667910
# 9      kitchen            3        0.656440       0.064906       0.591581
# 10      indoor            3        0.730329       0.063108       0.661479
# 11      person            1        0.870903            NaN       0.870903
#
#     max_class_acc
# 0        0.771429
# 1        0.791349
# 2        0.942568
# 3        0.991870
# 4        0.736842
# 5        0.848297
# 6        0.927273
# 7        0.920821
# 8        0.813953
# 9        0.721393
# 10       0.785425
# 11       0.870903
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.643817  0.013441   0.000000    0.002688  0.016129   0.079301
# animal       0.004304  0.899570   0.002152    0.000717  0.004304   0.007891
# appliance    0.000000  0.012579   0.861635    0.018868  0.012579   0.044025
# electronic   0.015929  0.001770   0.056637    0.775221  0.000000   0.031858
# food         0.002311  0.005393   0.005393    0.000770  0.909091   0.013097
# furniture    0.044794  0.011299   0.008878    0.011703  0.002421   0.791768
# indoor       0.018845  0.003647   0.006687    0.052888  0.009119   0.034650
# kitchen      0.010421  0.001359   0.019937    0.005437  0.009062   0.063888
# outdoor      0.007968  0.006640   0.000000    0.001328  0.000000   0.001328
# person       0.065732  0.010561   0.000273    0.000819  0.000455   0.014567
# sports       0.032895  0.004934   0.003289    0.004934  0.024671   0.004934
# vehicle      0.044370  0.009694   0.004101    0.000746  0.000000   0.009321
#
#               indoor   kitchen   outdoor    person    sports   vehicle
# accessory   0.018817  0.001344  0.049731  0.072581  0.080645  0.021505
# animal      0.012912  0.002869  0.014347  0.007891  0.027260  0.015782
# appliance   0.031447  0.000000  0.000000  0.000000  0.000000  0.018868
# electronic  0.051327  0.014159  0.008850  0.010619  0.019469  0.014159
# food        0.005393  0.024653  0.004622  0.003852  0.023112  0.002311
# furniture   0.015335  0.032688  0.002018  0.039952  0.007667  0.031477
# indoor      0.798784  0.044985  0.006079  0.003040  0.015198  0.006079
# kitchen     0.043951  0.831899  0.001359  0.001359  0.009968  0.001359
# outdoor     0.013280  0.003984  0.895086  0.015936  0.005312  0.049137
# person      0.001639  0.001730  0.005371  0.870903  0.014658  0.013292
# sports      0.011513  0.003289  0.004934  0.019737  0.873355  0.011513
# vehicle     0.003356  0.002610  0.043997  0.018270  0.006339  0.857196
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    accessory      744  0.626344                    0.017473
# 1      kitchen     2207  0.660172                    0.171726
# 2    furniture     2478  0.678773                    0.112994
# 3    appliance      159  0.698113                    0.163522
# 4       sports      608  0.702303                    0.171053
# 5   electronic      565  0.716814                    0.058407
# 6         food     1298  0.735747                    0.173344
# 7       indoor     1645  0.737386                    0.061398
# 8      outdoor      753  0.775564                    0.119522
# 9       animal     1394  0.821377                    0.078192
# 10     vehicle     2682  0.829978                    0.027218
# 11      person    10984  0.870903                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.356183               sports
# 1                      0.168101            furniture
# 2                      0.208232            accessory
# 3                      0.138365            furniture
# 4                      0.126645            accessory
# 5                      0.224779            appliance
# 6                      0.090909              kitchen
# 7                      0.201216           electronic
# 8                      0.104914              vehicle
# 9                      0.100430               sports
# 10                     0.142804            accessory
# 11                     0.129097            accessory
#
#     top_wrong_superclass_frac
# 0                    0.080645
# 1                    0.063888
# 2                    0.044794
# 3                    0.044025
# 4                    0.032895
# 5                    0.056637
# 6                    0.024653
# 7                    0.052888
# 8                    0.049137
# 9                    0.027260
# 10                   0.044370
# 11                   0.065732
# ******************************TASK 3******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    appliance            4        0.449652       0.303805       0.000000
# 1    accessory            3        0.549269       0.205007       0.321937
# 2         food            7        0.679000       0.132998       0.506849
# 3       indoor            5        0.672682       0.106667       0.500000
# 4   electronic            5        0.697291       0.102109       0.582090
# 5       sports            7        0.692153       0.100186       0.551020
# 6       animal            8        0.767977       0.099109       0.602381
# 7      vehicle            6        0.778958       0.074958       0.655405
# 8      outdoor            4        0.718271       0.074957       0.625000
# 9      kitchen            6        0.609728       0.065584       0.503268
# 10   furniture            4        0.653480       0.053869       0.605809
# 11      person            1        0.790422            NaN       0.790422
#
#     max_class_acc
# 0        0.657143
# 1        0.720102
# 2        0.915541
# 3        0.749343
# 4        0.849624
# 5        0.851562
# 6        0.919149
# 7        0.876471
# 8        0.802469
# 9        0.694239
# 10       0.730650
# 11       0.790422
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.746835  0.007911   0.000000    0.069620  0.006329   0.023734
# animal       0.009314  0.906373   0.000000    0.004412  0.001961   0.005882
# appliance    0.000000  0.000000   0.799451    0.016484  0.008242   0.030220
# electronic   0.013528  0.000000   0.026015    0.783559  0.002081   0.035380
# food         0.010820  0.009112   0.001139    0.000569  0.917426   0.003986
# furniture    0.033495  0.010089   0.008071    0.031477  0.001211   0.732849
# indoor       0.016376  0.008188   0.006004    0.071507  0.013646   0.026201
# kitchen      0.009453  0.000295   0.017430    0.023338  0.023338   0.031610
# outdoor      0.025221  0.008827   0.002522    0.008827  0.001261   0.000000
# person       0.070102  0.016479   0.000637    0.041879  0.000546   0.030135
# sports       0.024618  0.021222   0.000000    0.017827  0.022071   0.005942
# vehicle      0.030478  0.010266   0.001925    0.015720  0.000000   0.008341
#
#               indoor   kitchen   outdoor    person    sports   vehicle
# accessory   0.011076  0.007911  0.021361  0.024525  0.047468  0.033228
# animal      0.014216  0.000490  0.016667  0.005882  0.026961  0.007843
# appliance   0.035714  0.063187  0.010989  0.000000  0.021978  0.013736
# electronic  0.086368  0.026015  0.002081  0.003122  0.011446  0.010406
# food        0.014806  0.025626  0.000000  0.000000  0.014806  0.001708
# furniture   0.023406  0.090799  0.004843  0.018160  0.014124  0.031477
# indoor      0.767467  0.058406  0.009279  0.003821  0.014192  0.004913
# kitchen     0.075628  0.784047  0.005022  0.001477  0.024225  0.004136
# outdoor     0.008827  0.002522  0.875158  0.008827  0.018916  0.039092
# person      0.006646  0.002822  0.013474  0.790422  0.012291  0.014567
# sports      0.018676  0.005942  0.009338  0.007640  0.831070  0.035654
# vehicle     0.000642  0.002246  0.039782  0.009945  0.009625  0.871030
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    accessory     1264  0.562500                    0.184335
# 1    appliance      364  0.585165                    0.214286
# 2      kitchen     3385  0.610044                    0.174003
# 3    furniture     2478  0.644471                    0.088378
# 4   electronic      961  0.670135                    0.113424
# 5         food     1756  0.694191                    0.223235
# 6      outdoor      793  0.709962                    0.165195
# 7       sports     1178  0.717317                    0.113752
# 8       indoor     1832  0.729258                    0.038210
# 9       animal     2040  0.743627                    0.162745
# 10     vehicle     3117  0.779275                    0.091755
# 11      person    10984  0.790422                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.253165           electronic
# 1                      0.200549              kitchen
# 2                      0.215953               indoor
# 3                      0.267151              kitchen
# 4                      0.216441               indoor
# 5                      0.082574              kitchen
# 6                      0.124842              vehicle
# 7                      0.168930              vehicle
# 8                      0.232533           electronic
# 9                      0.093627               sports
# 10                     0.128970              outdoor
# 11                     0.209578            accessory
#
#     top_wrong_superclass_frac
# 0                    0.069620
# 1                    0.063187
# 2                    0.075628
# 3                    0.090799
# 4                    0.086368
# 5                    0.025626
# 6                    0.039092
# 7                    0.035654
# 8                    0.071507
# 9                    0.026961
# 10                   0.039782
# 11                   0.070102
# ******************************TASK 4******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    appliance            5        0.505557       0.301866       0.000000
# 1       indoor            7        0.678045       0.203472       0.312500
# 2    accessory            5        0.560969       0.198773       0.330484
# 3       animal           10        0.780704       0.133710       0.523810
# 4         food           10        0.645242       0.130830       0.410959
# 5       sports           10        0.647753       0.124932       0.408163
# 6   electronic            6        0.632291       0.117428       0.456274
# 7      outdoor            5        0.683714       0.098607       0.559796
# 8      kitchen            9        0.572183       0.092103       0.434641
# 9      vehicle            8        0.749771       0.090395       0.620253
# 10   furniture            4        0.666759       0.075324       0.584416
# 11      person            1        0.800892            NaN       0.800892
#
#     max_class_acc
# 0        0.801887
# 1        1.000000
# 2        0.722222
# 3        0.952830
# 4        0.891892
# 5        0.805031
# 6        0.819549
# 7        0.818182
# 8        0.723270
# 9        0.841176
# 10       0.761610
# 11       0.800892
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.745649  0.009545   0.005053    0.051656  0.005615   0.020775
# animal       0.002400  0.912400   0.001200    0.000400  0.006000   0.003600
# appliance    0.004255  0.002128   0.787234    0.017021  0.029787   0.031915
# electronic   0.034913  0.000831   0.025769    0.734830  0.017456   0.030756
# food         0.005693  0.007211   0.000380    0.001898  0.922581   0.007211
# furniture    0.079500  0.006053   0.010089    0.007264  0.007264   0.706215
# indoor       0.023529  0.010160   0.012299    0.029412  0.036898   0.036898
# kitchen      0.010951  0.002053   0.018024    0.009126  0.061145   0.041752
# outdoor      0.042159  0.007589   0.000843    0.006745  0.000843   0.043845
# person       0.056901  0.037327   0.000819    0.017571  0.002003   0.012382
# sports       0.018425  0.012284   0.003908    0.007817  0.015075   0.006142
# vehicle      0.010199  0.007139   0.001275    0.005354  0.000000   0.003060
#
#               indoor   kitchen   outdoor    person    sports   vehicle
# accessory   0.015160  0.008984  0.023021  0.039304  0.037619  0.037619
# animal      0.014000  0.002000  0.014800  0.005200  0.027600  0.010400
# appliance   0.019149  0.093617  0.006383  0.000000  0.000000  0.008511
# electronic  0.104738  0.031588  0.002494  0.006650  0.006650  0.003325
# food        0.010626  0.036812  0.000759  0.000380  0.005313  0.001139
# furniture   0.015335  0.073446  0.043987  0.016142  0.017756  0.016949
# indoor      0.754011  0.063102  0.010695  0.006417  0.013369  0.003209
# kitchen     0.048825  0.782569  0.012320  0.002053  0.007757  0.003422
# outdoor     0.010961  0.009275  0.768971  0.016020  0.023609  0.069140
# person      0.002731  0.002913  0.018390  0.800892  0.030044  0.018026
# sports      0.023451  0.008375  0.025126  0.012842  0.817979  0.048576
# vehicle     0.000765  0.002550  0.025242  0.012239  0.017593  0.914584
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    accessory     1781  0.530039                    0.215609
# 1      kitchen     4383  0.586356                    0.196213
# 2   electronic     1203  0.608479                    0.126351
# 3    furniture     2478  0.620258                    0.085956
# 4    appliance      470  0.636170                    0.151064
# 5      outdoor     1186  0.651771                    0.117201
# 6         food     2635  0.663378                    0.259203
# 7       sports     1791  0.673925                    0.144054
# 8       indoor     1870  0.714439                    0.039572
# 9      vehicle     3922  0.720296                    0.194289
# 10      animal     2500  0.750400                    0.162000
# 11      person    10984  0.800892                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.254351           electronic
# 1                      0.217431                 food
# 2                      0.265170               indoor
# 3                      0.293785            accessory
# 4                      0.212766              kitchen
# 5                      0.231029              vehicle
# 6                      0.077419              kitchen
# 7                      0.182021              vehicle
# 8                      0.245989              kitchen
# 9                      0.085416              outdoor
# 10                     0.087600               sports
# 11                     0.199108            accessory
#
#     top_wrong_superclass_frac
# 0                    0.051656
# 1                    0.061145
# 2                    0.104738
# 3                    0.079500
# 4                    0.093617
# 5                    0.069140
# 6                    0.036812
# 7                    0.048576
# 8                    0.063102
# 9                    0.025242
# 10                   0.027600
# 11                   0.056901

# %%
tasks = [(l2_normalize(t1_euclidean_embeddings_known), t1_euclidean_labels_known),
         (l2_normalize(t2_euclidean_embeddings_known), t2_euclidean_labels_known),
         (l2_normalize(t3_euclidean_embeddings_known), t3_euclidean_labels_known),
         (l2_normalize(t4_euclidean_embeddings_known), t4_euclidean_labels_known)]

results, replay_buffer, per_task_details = run_incremental_fewshot(tasks, shot_size=20, k=2)

print(pd.DataFrame(results))

y_true3 = per_task_details[3]["y_true"]
y_pred3 = per_task_details[3]["y_pred"]

y_true2 = per_task_details[2]["y_true"]
y_pred2 = per_task_details[2]["y_pred"]

y_true1 = per_task_details[1]["y_true"]
y_pred1 = per_task_details[1]["y_pred"]

y_true0 = per_task_details[0]["y_true"]
y_pred0 = per_task_details[0]["y_pred"]

print("******************************TASK 1******************************")
print(per_task_details[0]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true0, y_pred0, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true0, y_pred0, superclass_map)
print(task4_failure)
print("******************************TASK 2******************************")
print(per_task_details[1]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true1, y_pred1, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true1, y_pred1, superclass_map)
print(task4_failure)
print("******************************TASK 3******************************")
print(per_task_details[2]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true2, y_pred2, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true2, y_pred2, superclass_map)
print(task4_failure)
print("******************************TASK 4******************************")
print(per_task_details[3]["superclass_variation_table"])
task4_sc_cm = superclass_confusion_table(y_true3, y_pred3, superclass_map)
print(task4_sc_cm)

task4_failure = superclass_failure_breakdown(y_true3, y_pred3, superclass_map)
print(task4_failure)
# Out:
#    task  accuracy  num_seen_classes  macro_class_acc  class_acc_std  \
# 0     1  0.871744                20         0.871774       0.067989
# 1     2  0.797275                40         0.705436       0.193682
# 2     3  0.702394                60         0.660154       0.143827
# 3     4  0.690826                80         0.637527       0.174328
#
#    macro_superclass_acc  superclass_acc_std
# 0              0.903625            0.049896
# 1              0.839906            0.078475
# 2              0.808670            0.050488
# 3              0.802284            0.069430
# ******************************TASK 1******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    furniture            2        0.827542       0.108669       0.750702
# 1    appliance            2        0.790810       0.044423       0.759398
# 2         food            2        0.795375       0.044100       0.764192
# 3       sports            2        0.953247       0.041631       0.923810
# 4      vehicle            2        0.939900       0.030545       0.918301
# 5      outdoor            2        0.928133       0.022692       0.912088
# 6       animal            3        0.909140       0.021244       0.884615
# 7      kitchen            2        0.839234       0.019260       0.825616
# 8    accessory            1        0.855956            NaN       0.855956
# 9   electronic            1        0.791367            NaN       0.791367
# 10      indoor            1        0.912250            NaN       0.912250
#
#     max_class_acc
# 0        0.904382
# 1        0.822222
# 2        0.826558
# 3        0.982684
# 4        0.961498
# 5        0.944179
# 6        0.921875
# 7        0.852853
# 8        0.855956
# 9        0.791367
# 10       0.912250
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.855956  0.011080   0.000000    0.005540  0.008310   0.027701
# animal       0.016867  0.928916   0.006024    0.001205  0.002410   0.031325
# appliance    0.005618  0.000000   0.926966    0.000000  0.000000   0.028090
# electronic   0.014388  0.003597   0.118705    0.791367  0.003597   0.035971
# food         0.011706  0.006689   0.005017    0.000000  0.891304   0.048495
# furniture    0.020669  0.004921   0.011811    0.000984  0.002461   0.857283
# indoor       0.003475  0.000000   0.032146    0.001738  0.006950   0.020851
# kitchen      0.012611  0.000000   0.015579    0.000000  0.046736   0.012611
# outdoor      0.002786  0.000000   0.005571    0.001393  0.000000   0.006964
# sports       0.011905  0.000000   0.002976    0.002976  0.002976   0.005952
# vehicle      0.001346  0.000449   0.005386    0.000000  0.001346   0.006284
#
#               indoor   kitchen   outdoor    sports   vehicle
# accessory   0.000000  0.019391  0.027701  0.019391  0.024931
# animal      0.000000  0.001205  0.003614  0.000000  0.008434
# appliance   0.011236  0.022472  0.000000  0.000000  0.005618
# electronic  0.003597  0.010791  0.014388  0.000000  0.003597
# food        0.000000  0.026756  0.000000  0.001672  0.008361
# furniture   0.011319  0.081693  0.000492  0.000000  0.008366
# indoor      0.912250  0.015639  0.001738  0.000000  0.005213
# kitchen     0.005935  0.902077  0.002226  0.000742  0.001484
# outdoor     0.000000  0.004178  0.949861  0.000000  0.029248
# sports      0.000000  0.000000  0.000000  0.964286  0.008929
# vehicle     0.000449  0.002693  0.021993  0.000449  0.959605
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    furniture     2032  0.769685                    0.087598
# 1    appliance      178  0.775281                    0.151685
# 2   electronic      278  0.791367                    0.000000
# 3         food      598  0.802676                    0.088629
# 4      kitchen     1348  0.832344                    0.069733
# 5    accessory      361  0.855956                    0.000000
# 6       animal      830  0.912048                    0.016867
# 7       indoor     1151  0.912250                    0.000000
# 8      outdoor      718  0.940111                    0.009749
# 9      vehicle     2228  0.955566                    0.004039
# 10      sports      336  0.964286                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.142717              kitchen
# 1                      0.073034            furniture
# 2                      0.208633            appliance
# 3                      0.108696            furniture
# 4                      0.097923                 food
# 5                      0.144044            furniture
# 6                      0.071084            furniture
# 7                      0.087750            appliance
# 8                      0.050139              vehicle
# 9                      0.040395              outdoor
# 10                     0.035714            accessory
#
#     top_wrong_superclass_frac
# 0                    0.081693
# 1                    0.028090
# 2                    0.118705
# 3                    0.048495
# 4                    0.046736
# 5                    0.027701
# 6                    0.031325
# 7                    0.032146
# 8                    0.029248
# 9                    0.021993
# 10                   0.011905
# ******************************TASK 2******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    appliance            3        0.509997       0.441771       0.000000
# 1    accessory            2        0.579270       0.317773       0.354571
# 2       animal            5        0.724886       0.242700       0.317308
# 3       sports            4        0.577154       0.226449       0.264069
# 4         food            5        0.716875       0.160391       0.558952
# 5    furniture            4        0.708137       0.140448       0.545817
# 6      vehicle            4        0.842502       0.127797       0.663399
# 7      outdoor            3        0.792368       0.094973       0.703297
# 8   electronic            3        0.716703       0.084509       0.633094
# 9       indoor            3        0.769354       0.066260       0.692884
# 10     kitchen            3        0.695177       0.065581       0.622047
# 11      person            1        0.888121            NaN       0.888121
#
#     max_class_acc
# 0        0.774436
# 1        0.803970
# 2        0.934473
# 3        0.761905
# 4        0.950980
# 5        0.873874
# 6        0.962406
# 7        0.892308
# 8        0.802083
# 9        0.809731
# 10       0.748768
# 11       0.888121
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.619110  0.030105   0.001309    0.002618  0.013089   0.100785
# animal       0.010388  0.889197   0.001385    0.000693  0.002770   0.008310
# appliance    0.000000  0.011173   0.905028    0.011173  0.011173   0.039106
# electronic   0.016807  0.001681   0.077311    0.769748  0.000000   0.023529
# food         0.009644  0.005935   0.000742    0.001484  0.909496   0.011869
# furniture    0.047260  0.028991   0.005560    0.012311  0.002383   0.797458
# indoor       0.015522  0.004179   0.022090    0.034627  0.008358   0.031642
# kitchen      0.013858  0.001788   0.016540    0.005364  0.011176   0.014752
# outdoor      0.021711  0.011494   0.000000    0.001277  0.001277   0.000000
# person       0.058941  0.020739   0.000364    0.001001  0.000546   0.007913
# sports       0.038580  0.001543   0.001543    0.004630  0.037037   0.006173
# vehicle      0.055474  0.009184   0.004041    0.000735  0.000000   0.008450
#
#               indoor   kitchen   outdoor    person    sports   vehicle
# accessory   0.030105  0.003927  0.036649  0.082461  0.052356  0.027487
# animal      0.006925  0.002078  0.004848  0.010388  0.051939  0.011080
# appliance   0.016760  0.005587  0.000000  0.000000  0.000000  0.000000
# electronic  0.048739  0.020168  0.008403  0.008403  0.015126  0.010084
# food        0.009644  0.019288  0.001484  0.001484  0.025964  0.002967
# furniture   0.021446  0.025814  0.001191  0.040508  0.004766  0.012311
# indoor      0.816119  0.041791  0.008955  0.004179  0.011343  0.001194
# kitchen     0.049173  0.873491  0.002235  0.001341  0.008494  0.001788
# outdoor     0.019157  0.002554  0.877395  0.008940  0.014049  0.042146
# person      0.002638  0.001182  0.001001  0.888121  0.007368  0.010187
# sports      0.012346  0.003086  0.003086  0.018519  0.862654  0.010802
# vehicle     0.004041  0.001837  0.017267  0.018369  0.009552  0.871051
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0       sports      648  0.550926                    0.311728
# 1    accessory      764  0.591623                    0.027487
# 2    furniture     2518  0.679110                    0.118348
# 3   electronic      595  0.690756                    0.078992
# 4      kitchen     2237  0.693339                    0.180152
# 5         food     1348  0.720326                    0.189169
# 6       animal     1444  0.744460                    0.144737
# 7    appliance      179  0.765363                    0.139665
# 8      outdoor      783  0.781609                    0.095785
# 9       indoor     1675  0.790448                    0.025672
# 10     vehicle     2722  0.841661                    0.029390
# 11      person    10994  0.888121                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.137346            accessory
# 1                      0.380890            furniture
# 2                      0.202542            accessory
# 3                      0.230252            appliance
# 4                      0.126509               indoor
# 5                      0.090504               sports
# 6                      0.110803               sports
# 7                      0.094972            furniture
# 8                      0.122605              vehicle
# 9                      0.183881              kitchen
# 10                     0.128949            accessory
# 11                     0.111879            accessory
#
#     top_wrong_superclass_frac
# 0                    0.038580
# 1                    0.100785
# 2                    0.047260
# 3                    0.077311
# 4                    0.049173
# 5                    0.025964
# 6                    0.051939
# 7                    0.039106
# 8                    0.042146
# 9                    0.041791
# 10                   0.055474
# 11                   0.058941
# ******************************TASK 3******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    appliance            4        0.472669       0.315483       0.000000
# 1    accessory            3        0.498254       0.143117       0.335180
# 2       indoor            5        0.663965       0.142320       0.423077
# 3      vehicle            6        0.732311       0.139222       0.470588
# 4       animal            8        0.728520       0.133745       0.534884
# 5         food            7        0.679175       0.131890       0.510917
# 6       sports            7        0.666713       0.110052       0.525424
# 7    furniture            4        0.642966       0.108588       0.503268
# 8   electronic            5        0.668564       0.088760       0.574661
# 9      kitchen            6        0.638183       0.085377       0.499438
# 10     outdoor            4        0.689661       0.057067       0.607656
# 11      person            1        0.758323            NaN       0.758323
#
#     max_class_acc
# 0        0.644444
# 1        0.602978
# 2        0.779006
# 3        0.850000
# 4        0.918367
# 5        0.911765
# 6        0.828221
# 7        0.753754
# 8        0.797203
# 9        0.726108
# 10       0.740000
# 11       0.758323
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.776662  0.007728   0.000773    0.014683  0.004637   0.017002
# animal       0.010849  0.894340   0.000000    0.000943  0.007547   0.006604
# appliance    0.002538  0.000000   0.827411    0.025381  0.005076   0.020305
# electronic   0.015826  0.002967   0.037587    0.791296  0.004946   0.013848
# food         0.007667  0.007667   0.004381    0.002191  0.915115   0.004929
# furniture    0.055600  0.013900   0.008340    0.034948  0.001191   0.743050
# indoor       0.019660  0.006908   0.009033    0.064825  0.010627   0.024973
# kitchen      0.012482  0.000871   0.020029    0.027286  0.015675   0.030189
# outdoor      0.048019  0.015606   0.000000    0.000000  0.002401   0.000000
# person       0.160633  0.009551   0.000182    0.002820  0.000546   0.020284
# sports       0.033654  0.025641   0.000000    0.005609  0.025641   0.001603
# vehicle      0.067044  0.010072   0.001574    0.002203  0.000000   0.011961
#
#               indoor   kitchen   outdoor    person    sports   vehicle
# accessory   0.028594  0.003091  0.014683  0.017774  0.057960  0.056414
# animal      0.026887  0.000472  0.006604  0.011321  0.030189  0.004245
# appliance   0.043147  0.048223  0.007614  0.000000  0.000000  0.020305
# electronic  0.076162  0.040554  0.000000  0.003956  0.007913  0.004946
# food        0.022453  0.023001  0.000000  0.000000  0.009858  0.002738
# furniture   0.035743  0.046068  0.002383  0.021446  0.008737  0.028594
# indoor      0.784803  0.053135  0.008502  0.003719  0.010096  0.003719
# kitchen     0.074020  0.803774  0.002322  0.002032  0.006676  0.004644
# outdoor     0.063625  0.003601  0.764706  0.006002  0.055222  0.040816
# person      0.008459  0.001910  0.011461  0.758323  0.018374  0.007459
# sports      0.030449  0.006410  0.006410  0.009615  0.838141  0.016827
# vehicle     0.003462  0.001259  0.065785  0.006610  0.023607  0.806421
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    accessory     1294  0.509274                    0.267388
# 1    appliance      394  0.626904                    0.200508
# 2      outdoor      833  0.633854                    0.130852
# 3    furniture     2518  0.636616                    0.106434
# 4      kitchen     3445  0.639478                    0.164296
# 5   electronic     1011  0.647873                    0.143422
# 6         food     1826  0.693319                    0.221796
# 7       sports     1248  0.699519                    0.138622
# 8       animal     2120  0.718396                    0.175943
# 9      vehicle     3177  0.729619                    0.076802
# 10      indoor     1882  0.733794                    0.051010
# 11      person    10994  0.758323                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.223338               sports
# 1                      0.172589              kitchen
# 2                      0.235294               indoor
# 3                      0.256950            accessory
# 4                      0.196226               indoor
# 5                      0.208704               indoor
# 6                      0.084885              kitchen
# 7                      0.161859            accessory
# 8                      0.105660               sports
# 9                      0.193579            accessory
# 10                     0.215197           electronic
# 11                     0.241677            accessory
#
#     top_wrong_superclass_frac
# 0                    0.057960
# 1                    0.048223
# 2                    0.063625
# 3                    0.055600
# 4                    0.074020
# 5                    0.076162
# 6                    0.023001
# 7                    0.033654
# 8                    0.030189
# 9                    0.067044
# 10                   0.064825
# 11                   0.160633
# ******************************TASK 4******************************
#     superclass  num_classes  mean_class_acc  std_class_acc  min_class_acc  \
# 0    appliance            5        0.519463       0.299160       0.000000
# 1       indoor            7        0.655533       0.242605       0.192308
# 2    accessory            5        0.544046       0.241610       0.188366
# 3       animal           10        0.759982       0.164612       0.469767
# 4      kitchen            9        0.538063       0.164332       0.170732
# 5         food           10        0.638785       0.145356       0.362445
# 6       sports           10        0.618630       0.135763       0.355932
# 7      outdoor            5        0.620872       0.113243       0.440000
# 8    furniture            4        0.647649       0.110141       0.555867
# 9   electronic            6        0.621795       0.106591       0.461538
# 10     vehicle            8        0.730562       0.097042       0.590123
# 11      person            1        0.809169            NaN       0.809169
#
#     max_class_acc
# 0        0.724138
# 1        1.000000
# 2        0.754266
# 3        0.965116
# 4        0.668639
# 5        0.915033
# 6        0.823256
# 7        0.703297
# 8        0.792793
# 9        0.783217
# 10       0.857143
# 11       0.809169
#             accessory    animal  appliance  electronic      food  furniture  \
# accessory    0.793555  0.007100   0.005461    0.048607  0.008192   0.008192
# animal       0.004231  0.903846   0.002308    0.000385  0.008846   0.002692
# appliance    0.001961  0.000000   0.819608    0.023529  0.013725   0.023529
# electronic   0.044339  0.001584   0.055424    0.731591  0.020586   0.012668
# food         0.005119  0.008410   0.003656    0.001828  0.916636   0.005850
# furniture    0.094519  0.009929   0.009929    0.015091  0.008737   0.695393
# indoor       0.028497  0.010881   0.018653    0.033161  0.046632   0.032642
# kitchen      0.013637  0.002012   0.022356    0.014085  0.055220   0.030181
# outdoor      0.067961  0.006472   0.000809    0.031553  0.001618   0.025890
# person       0.048754  0.022649   0.001455    0.023104  0.002820   0.007095
# sports       0.042306  0.012163   0.002115    0.007403  0.026970   0.005288
# vehicle      0.013743  0.002999   0.000500    0.015992  0.000250   0.001999
#
#               indoor   kitchen   outdoor    person    sports   vehicle
# accessory   0.015292  0.007100  0.018569  0.028946  0.032769  0.026215
# animal      0.019231  0.003077  0.018846  0.003846  0.022692  0.010000
# appliance   0.015686  0.080392  0.007843  0.001961  0.003922  0.007843
# electronic  0.076010  0.042755  0.002375  0.007126  0.003959  0.001584
# food        0.010238  0.041316  0.001463  0.000366  0.004022  0.001097
# furniture   0.019063  0.055203  0.040111  0.020254  0.017871  0.013900
# indoor      0.753368  0.052332  0.006736  0.004145  0.009845  0.003109
# kitchen     0.054102  0.786720  0.010731  0.001565  0.006930  0.002459
# outdoor     0.029935  0.017799  0.729773  0.009709  0.025890  0.052589
# person      0.004912  0.001910  0.018919  0.809169  0.044843  0.014371
# sports      0.022739  0.012692  0.021153  0.007932  0.787943  0.051296
# vehicle     0.002749  0.002749  0.032984  0.012494  0.013743  0.899800
#     superclass  n_query       acc  same_superclass_error_rate  \
# 0    accessory     1831  0.517750                    0.275806
# 1      kitchen     4473  0.568969                    0.217751
# 2    furniture     2518  0.599682                    0.095711
# 3   electronic     1263  0.608868                    0.122724
# 4    appliance      510  0.633333                    0.186275
# 5       sports     1891  0.644104                    0.143839
# 6      outdoor     1236  0.644822                    0.084951
# 7         food     2735  0.654845                    0.261792
# 8      vehicle     4002  0.698401                    0.201399
# 9       indoor     1930  0.711399                    0.041969
# 10      animal     2600  0.728077                    0.175769
# 11      person    10994  0.809169                    0.000000
#
#     cross_superclass_error_rate top_wrong_superclass  \
# 0                      0.206445           electronic
# 1                      0.213280                 food
# 2                      0.304607            accessory
# 3                      0.268409               indoor
# 4                      0.180392              kitchen
# 5                      0.212057              vehicle
# 6                      0.270227            accessory
# 7                      0.083364              kitchen
# 8                      0.100200              outdoor
# 9                      0.246632              kitchen
# 10                     0.096154               sports
# 11                     0.190831            accessory
#
#     top_wrong_superclass_frac
# 0                    0.048607
# 1                    0.055220
# 2                    0.094519
# 3                    0.076010
# 4                    0.080392
# 5                    0.051296
# 6                    0.067961
# 7                    0.041316
# 8                    0.032984
# 9                    0.052332
# 10                   0.022692
# 11                   0.048754
